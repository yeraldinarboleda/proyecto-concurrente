# %%
# !pip install pycuda
# Out:
# Collecting pycuda
#   Downloading pycuda-2024.1.tar.gz (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 13.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pytools>=2011.2 (from pycuda)
#   Downloading pytools-2024.1.5-py2.py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.1/88.1 kB 15.7 MB/s eta 0:00:00
# Collecting appdirs>=1.4.0 (from pycuda)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting mako (from pycuda)
#   Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 13.1 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from pytools>=2011.2->pycuda) (4.2.2)
# Requirement already satisfied: typing-extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from pytools>=2011.2->pycuda) (4.12.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from mako->pycuda) (2.1.5)
# Building wheels for collected packages: pycuda
#   Building wheel for pycuda (pyproject.toml) ... done
#   Created wheel for pycuda: filename=pycuda-2024.1-cp310-cp310-linux_x86_64.whl size=661204 sha256=ae3b58ae1973bf5b188f9a1791ba22432cd80d06eac0ec055bce3d42adceed5d
#   Stored in directory: /root/.cache/pip/wheels/12/34/d2/9a349255a4eca3a486d82c79d21e138ce2ccd90f414d9d72b8
# Successfully built pycuda
# Installing collected packages: appdirs, pytools, mako, pycuda
# Successfully installed appdirs-1.4.4 mako-1.3.5 pycuda-2024.1 pytools-2024.1.5

# %%
# !pip install  bio
# Out:
# Collecting bio
#   Downloading bio-1.7.1-py3-none-any.whl (280 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.0/281.0 kB 5.3 MB/s eta 0:00:00
# Collecting biopython>=1.80 (from bio)
#   Downloading biopython-1.83-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 16.2 MB/s eta 0:00:00
# Collecting gprofiler-official (from bio)
#   Downloading gprofiler_official-1.0.0-py3-none-any.whl (9.3 kB)
# Collecting mygene (from bio)
#   Downloading mygene-3.2.2-py2.py3-none-any.whl (5.4 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from bio) (2.0.3)
# Requirement already satisfied: pooch in /usr/local/lib/python3.10/dist-packages (from bio) (1.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bio) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from bio) (4.66.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from biopython>=1.80->bio) (1.25.2)
# Collecting biothings-client>=0.2.6 (from mygene->bio)
#   Downloading biothings_client-0.3.1-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->bio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->bio) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->bio) (2024.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch->bio) (4.2.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pooch->bio) (24.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bio) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bio) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bio) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bio) (2024.6.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->bio) (1.16.0)
# Installing collected packages: biopython, gprofiler-official, biothings-client, mygene, bio
# Successfully installed bio-1.7.1 biopython-1.83 biothings-client-0.3.1 gprofiler-official-1.0.0 mygene-3.2.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import gc
import psutil
import os
import argparse
import numpy as np
import matplotlib.pyplot as plt
import time

import pycuda.driver as cuda
import pycuda.autoinit
from pycuda.compiler import SourceModule
from Bio import SeqIO
import matplotlib

# Cambiar el backend a Agg
matplotlib.use('Agg')

def read_fasta(file_path):
    """Lee una o más secuencias de un archivo FASTA y las concatena"""
    sequences = []
    with open(file_path, "r") as file:
        for seq_record in SeqIO.parse(file, "fasta"):
            sequences.append(str(seq_record.seq))
    return ''.join(sequences)

def estimate_remaining_time(start_time, current_step, total_steps):
    """Estima el tiempo restante para completar la ejecución"""
    elapsed_time = time.time() - start_time
    if elapsed_time < 1e-6:
        return float('inf')
    steps_per_second = current_step / elapsed_time
    remaining_steps = total_steps - current_step
    if steps_per_second <= 0:
        return float('inf')
    estimated_remaining_time = remaining_steps / steps_per_second
    return estimated_remaining_time

def monitor_memory(used_bytes, max_system_percentage):
    """Monitoriza el uso de memoria y devuelve True si se excede el umbral"""
    process = psutil.Process(os.getpid())
    memory_info = process.memory_info()
    return memory_info.rss > used_bytes or psutil.virtual_memory().percent > max_system_percentage

def create_dotplot_gpu(seq1, seq2, output_dir, window_size=500, step_size=100, memory_limit=5*1024**3, max_system_memory=85):
    """Crea y dibuja un dotplot por partes usando una ventana deslizante en la GPU"""
    len1, len2 = len(seq1), len(seq2)
    total_steps = ((len1 - window_size) // step_size + 1) * ((len2 - window_size) // step_size + 1)
    current_step = 0
    start_time = time.time()
    last_save_time = start_time
    save_interval = 10 * 60  # 60 minutos en segundos (1 hora)
    image_counter = 0

    os.makedirs(output_dir, exist_ok=True)
    elapsed_times = []

    # Kernel de CUDA para crear el dotplot
    kernel_code = """
    __global__ void dotplot_kernel(unsigned char* seq1, unsigned char* seq2, int window_size, int* result) {
        int idx = threadIdx.x + blockIdx.x * blockDim.x;
        int idy = threadIdx.y + blockIdx.y * blockDim.y;

        if (idx < window_size && idy < window_size) {
            result[idx * window_size + idy] = (seq1[idx] == seq2[idy]);
        }
    }
    """
    mod = SourceModule(kernel_code)
    dotplot_kernel = mod.get_function("dotplot_kernel")

    for i in range(0, len1 - window_size + 1, step_size):
        for j in range(0, len2 - window_size + 1, step_size):

            if monitor_memory(memory_limit, max_system_memory):
                print("Uso de memoria cerca del límite. Liberando memoria.")
                gc.collect()
                continue

            step_start_time = time.time()

            # Convertir las secuencias a arrays de bytes (más compacto que arrays de caracteres)
            window1 = np.frombuffer(seq1[i:i+window_size].encode('utf-8'), dtype=np.uint8)
            window2 = np.frombuffer(seq2[j:j+window_size].encode('utf-8'), dtype=np.uint8)

            # Asignar memoria en la GPU
            seq1_gpu = cuda.mem_alloc(window1.nbytes)
            seq2_gpu = cuda.mem_alloc(window2.nbytes)
            result_gpu = cuda.mem_alloc(window_size * window_size * np.int32(0).nbytes)

            # Copiar datos a la GPU
            cuda.memcpy_htod(seq1_gpu, window1)
            cuda.memcpy_htod(seq2_gpu, window2)

            # Definir el tamaño de los bloques y la grilla
            block_size = (32, 32, 1)
            grid_size = (window_size // 32 + 1, window_size // 32 + 1, 1)

            # Ejecutar el kernel
            dotplot_kernel(seq1_gpu, seq2_gpu, np.int32(window_size), result_gpu, block=block_size, grid=grid_size)

            # Copiar el resultado de vuelta a la CPU
            result = np.empty((window_size, window_size), dtype=np.int32)
            cuda.memcpy_dtoh(result, result_gpu)

            fig, ax = plt.subplots(figsize=(10, 10))
            ax.imshow(result, cmap='gray_r', extent=(j, j+window_size, i, i+window_size), origin='lower')

            step_elapsed_time = time.time() - step_start_time
            elapsed_times.append(step_elapsed_time)

            current_step += 1
            if current_step % 2000 == 0:
                elapsed_time = time.time() - start_time
                remaining_time = estimate_remaining_time(start_time, current_step, total_steps)
                print(f"Progreso: {current_step}/{total_steps} pasos completados. Tiempo transcurrido: {elapsed_time:.2f} segundos. Tiempo restante estimado: {remaining_time:.2f} segundos")

                current_time = time.time()
                if current_time - last_save_time >= save_interval:
                    image_counter += 1
                    image_path = os.path.join(output_dir, f'dotplot_{image_counter}.png')
                    plt.savefig(image_path)
                    print(f"Imagen intermedia guardada en {image_path}")
                    last_save_time = current_time

                gc.collect()

            plt.close(fig)  # Cierra la figura para liberar memoria

    final_image_path = os.path.join(output_dir, 'dotplot_final.png')
    plt.savefig(final_image_path)
    print(f"Dotplot final guardado en {final_image_path}")
    gc.collect()

def main(seq1_path, seq2_path, memory_limit, max_system_memory):
    overall_start_time = time.time()

    print("Leyendo secuencias...")
    read_start_time = time.time()
    seq1 = read_fasta(seq1_path)
    seq2 = read_fasta(seq2_path)
    read_elapsed_time = time.time() - read_start_time
    print(f"Tiempo de carga de datos: {read_elapsed_time:.2f} segundos")

    output_dir = os.path.join('.', 'Imagenes', 'Pycuda')

    print("Creando dotplot...")
    dotplot_start_time = time.time()
    create_dotplot_gpu(seq1, seq2, output_dir, memory_limit=memory_limit, max_system_memory=max_system_memory)
    dotplot_elapsed_time = time.time() - dotplot_start_time
    print(f"Tiempo de generación de imagen: {dotplot_elapsed_time:.2f} segundos")

    overall_elapsed_time = time.time() - overall_start_time
    print(f"Tiempo total de ejecución: {overall_elapsed_time:.2f} segundos")

# Configuración del entorno interactivo en Google Colab
import ipywidgets as widgets
from IPython.display import display
from google.colab import files

# Crear widgets de texto para las rutas de entrada
seq1_input = widgets.Text(description="Ruta Seq1:")
seq2_input = widgets.Text(description="Ruta Seq2:")
memory_limit_input = widgets.IntText(value=5, description='Límite de Memoria (GB):')
max_system_memory_input = widgets.IntSlider(value=85, min=0, max=100, description='Memoria Máxima del Sistema (%):')

# Crear un botón para activar el cálculo
run_button = widgets.Button(description='Ejecutar Análisis')

# Mostrar los widgets
display(seq1_input, seq2_input, memory_limit_input, max_system_memory_input, run_button)

# Definir la acción del clic del botón
def on_run_button_clicked(b):
    # Convierte el límite de memoria de GB a bytes para el script
    memory_limit_bytes = memory_limit_input.value * 1024**3
    main(seq1_input.value, seq2_input.value, memory_limit_bytes, max_system_memory_input.value)

# Vincula el botón con la función
run_button.on_click(on_run_button_clicked)

# Permitir la subida de archivos desde el sistema local
uploaded = files.upload()
# Out:
# Progreso: 24000/2676496 pasos completados. Tiempo transcurrido: 479.17 segundos. Tiempo restante estimado: 52958.43 segundos
# Progreso: 26000/2676496 pasos completados. Tiempo transcurrido: 518.79 segundos. Tiempo restante estimado: 52886.59 segundos
# Progreso: 28000/2676496 pasos completados. Tiempo transcurrido: 560.04 segundos. Tiempo restante estimado: 52973.40 segundos
# Progreso: 30000/2676496 pasos completados. Tiempo transcurrido: 598.98 segundos. Tiempo restante estimado: 52840.21 segundos
# Progreso: 32000/2676496 pasos completados. Tiempo transcurrido: 638.95 segundos. Tiempo restante estimado: 52803.24 segundos
# Imagen intermedia guardada en ./Imagenes/Pycuda/dotplot_1.png
# Progreso: 34000/2676496 pasos completados. Tiempo transcurrido: 678.32 segundos. Tiempo restante estimado: 52719.15 segundos
# Progreso: 36000/2676496 pasos completados. Tiempo transcurrido: 718.13 segundos. Tiempo restante estimado: 52672.95 segundos
# Progreso: 38000/2676496 pasos completados. Tiempo transcurrido: 755.64 segundos. Tiempo restante estimado: 52467.29 segundos
# Progreso: 40000/2676496 pasos completados. Tiempo transcurrido: 793.50 segundos. Tiempo restante estimado: 52301.59 segundos
# Progreso: 42000/2676496 pasos completados. Tiempo transcurrido: 830.70 segundos. Tiempo restante estimado: 52106.76 segundos
# Progreso: 44000/2676496 pasos completados. Tiempo transcurrido: 870.31 segundos. Tiempo restante estimado: 52070.29 segundos
# Progreso: 46000/2676496 pasos completados. Tiempo transcurrido: 909.29 segundos. Tiempo restante estimado: 51997.35 segundos
# Progreso: 48000/2676496 pasos completados. Tiempo transcurrido: 947.05 segundos. Tiempo restante estimado: 51860.87 segundos
# Progreso: 50000/2676496 pasos completados. Tiempo transcurrido: 985.17 segundos. Tiempo restante estimado: 51751.14 segundos
# Progreso: 52000/2676496 pasos completados. Tiempo transcurrido: 1024.09 segundos. Tiempo restante estimado: 51686.79 segundos
# Progreso: 54000/2676496 pasos completados. Tiempo transcurrido: 1060.99 segundos. Tiempo restante estimado: 51526.82 segundos
# Progreso: 56000/2676496 pasos completados. Tiempo transcurrido: 1098.79 segundos. Tiempo restante estimado: 51417.36 segundos
# Progreso: 58000/2676496 pasos completados. Tiempo transcurrido: 1136.14 segundos. Tiempo restante estimado: 51292.75 segundos
# Progreso: 60000/2676496 pasos completados. Tiempo transcurrido: 1174.45 segundos. Tiempo restante estimado: 51215.91 segundos
# Progreso: 62000/2676496 pasos completados. Tiempo transcurrido: 1211.44 segundos. Tiempo restante estimado: 51085.56 segundos
# Progreso: 64000/2676496 pasos completados. Tiempo transcurrido: 1248.44 segundos. Tiempo restante estimado: 50961.67 segundos
# Imagen intermedia guardada en ./Imagenes/Pycuda/dotplot_2.png
# Progreso: 66000/2676496 pasos completados. Tiempo transcurrido: 1285.76 segundos. Tiempo restante estimado: 50855.53 segundos
# Progreso: 68000/2676496 pasos completados. Tiempo transcurrido: 1322.92 segundos. Tiempo restante estimado: 50747.56 segundos
# Progreso: 70000/2676496 pasos completados. Tiempo transcurrido: 1359.35 segundos. Tiempo restante estimado: 50616.12 segundos
# Progreso: 72000/2676496 pasos completados. Tiempo transcurrido: 1396.29 segundos. Tiempo restante estimado: 50508.67 segundos
# Progreso: 74000/2676496 pasos completados. Tiempo transcurrido: 1431.80 segundos. Tiempo restante estimado: 50354.62 segundos
# Progreso: 76000/2676496 pasos completados. Tiempo transcurrido: 1471.36 segundos. Tiempo restante estimado: 50345.49 segundos
# Progreso: 78000/2676496 pasos completados. Tiempo transcurrido: 1509.87 segundos. Tiempo restante estimado: 50299.84 segundos
# Progreso: 80000/2676496 pasos completados. Tiempo transcurrido: 1547.85 segundos. Tiempo restante estimado: 50237.43 segundos
# Progreso: 82000/2676496 pasos completados. Tiempo transcurrido: 1585.17 segundos. Tiempo restante estimado: 50155.22 segundos
# Progreso: 84000/2676496 pasos completados. Tiempo transcurrido: 1624.13 segundos. Tiempo restante estimado: 50125.60 segundos
# Progreso: 86000/2676496 pasos completados. Tiempo transcurrido: 1662.16 segundos. Tiempo restante estimado: 50067.69 segundos
# Progreso: 88000/2676496 pasos completados. Tiempo transcurrido: 1700.30 segundos. Tiempo restante estimado: 50013.95 segundos
# Progreso: 90000/2676496 pasos completados. Tiempo transcurrido: 1737.89 segundos. Tiempo restante estimado: 49945.00 segundos
# Progreso: 92000/2676496 pasos completados. Tiempo transcurrido: 1776.32 segundos. Tiempo restante estimado: 49900.97 segundos
# Progreso: 94000/2676496 pasos completados. Tiempo transcurrido: 1813.42 segundos. Tiempo restante estimado: 49820.64 segundos
# Progreso: 96000/2676496 pasos completados. Tiempo transcurrido: 1851.28 segundos. Tiempo restante estimado: 49762.84 segundos
# Imagen intermedia guardada en ./Imagenes/Pycuda/dotplot_3.png
# Progreso: 98000/2676496 pasos completados. Tiempo transcurrido: 1891.89 segundos. Tiempo restante estimado: 49777.82 segundos
# Progreso: 100000/2676496 pasos completados. Tiempo transcurrido: 1932.17 segundos. Tiempo restante estimado: 49782.28 segundos
# Progreso: 102000/2676496 pasos completados. Tiempo transcurrido: 1972.04 segundos. Tiempo restante estimado: 49774.69 segundos
# Progreso: 104000/2676496 pasos completados. Tiempo transcurrido: 2011.38 segundos. Tiempo restante estimado: 49752.64 segundos
# Progreso: 106000/2676496 pasos completados. Tiempo transcurrido: 2051.50 segundos. Tiempo restante estimado: 49748.90 segundos
# Progreso: 108000/2676496 pasos completados. Tiempo transcurrido: 2090.26 segundos. Tiempo restante estimado: 49711.33 segundos
# Progreso: 110000/2676496 pasos completados. Tiempo transcurrido: 2129.01 segundos. Tiempo restante estimado: 49673.70 segundos
# Progreso: 112000/2676496 pasos completados. Tiempo transcurrido: 2167.58 segundos. Tiempo restante estimado: 49631.60 segundos
# Progreso: 114000/2676496 pasos completados. Tiempo transcurrido: 2207.23 segundos. Tiempo restante estimado: 49614.26 segundos
# Progreso: 116000/2676496 pasos completados. Tiempo transcurrido: 2243.95 segundos. Tiempo restante estimado: 49531.28 segundos
# Progreso: 118000/2676496 pasos completados. Tiempo transcurrido: 2280.95 segundos. Tiempo restante estimado: 49455.85 segundos
# Progreso: 120000/2676496 pasos completados. Tiempo transcurrido: 2318.42 segundos. Tiempo restante estimado: 49391.95 segundos
# Progreso: 122000/2676496 pasos completados. Tiempo transcurrido: 2357.67 segundos. Tiempo restante estimado: 49365.99 segundos
# Progreso: 124000/2676496 pasos completados. Tiempo transcurrido: 2395.36 segundos. Tiempo restante estimado: 49307.66 segundos
# Progreso: 126000/2676496 pasos completados. Tiempo transcurrido: 2433.80 segundos. Tiempo restante estimado: 49264.99 segundos
# Progreso: 128000/2676496 pasos completados. Tiempo transcurrido: 2472.57 segundos. Tiempo restante estimado: 49229.10 segundos
# Imagen intermedia guardada en ./Imagenes/Pycuda/dotplot_4.png
# Progreso: 130000/2676496 pasos completados. Tiempo transcurrido: 2510.51 segundos. Tiempo restante estimado: 49177.04 segundos
# Progreso: 132000/2676496 pasos completados. Tiempo transcurrido: 2548.56 segundos. Tiempo restante estimado: 49127.26 segundos
# Progreso: 134000/2676496 pasos completados. Tiempo transcurrido: 2586.00 segundos. Tiempo restante estimado: 49066.43 segundos
# Progreso: 136000/2676496 pasos completados. Tiempo transcurrido: 2625.67 segundos. Tiempo restante estimado: 49047.78 segundos
# Progreso: 138000/2676496 pasos completados. Tiempo transcurrido: 2663.64 segundos. Tiempo restante estimado: 48997.47 segundos
# Progreso: 140000/2676496 pasos completados. Tiempo transcurrido: 2701.73 segundos. Tiempo restante estimado: 48949.57 segundos
# Progreso: 142000/2676496 pasos completados. Tiempo transcurrido: 2739.22 segundos. Tiempo restante estimado: 48891.16 segundos
# Progreso: 144000/2676496 pasos completados. Tiempo transcurrido: 2779.21 segundos. Tiempo restante estimado: 48877.28 segundos
# Progreso: 146000/2676496 pasos completados. Tiempo transcurrido: 2818.37 segundos. Tiempo restante estimado: 48848.42 segundos
# Progreso: 148000/2676496 pasos completados. Tiempo transcurrido: 2857.10 segundos. Tiempo restante estimado: 48811.86 segundos
# Progreso: 150000/2676496 pasos completados. Tiempo transcurrido: 2896.40 segundos. Tiempo restante estimado: 48785.01 segundos
# Progreso: 152000/2676496 pasos completados. Tiempo transcurrido: 2937.38 segundos. Tiempo restante estimado: 48785.57 segundos
# Progreso: 154000/2676496 pasos completados. Tiempo transcurrido: 2975.64 segundos. Tiempo restante estimado: 48740.44 segundos
# Progreso: 156000/2676496 pasos completados. Tiempo transcurrido: 3013.31 segundos. Tiempo restante estimado: 48686.13 segundos
# Progreso: 158000/2676496 pasos completados. Tiempo transcurrido: 3053.01 segundos. Tiempo restante estimado: 48664.44 segundos
# Progreso: 160000/2676496 pasos completados. Tiempo transcurrido: 3091.51 segundos. Tiempo restante estimado: 48623.56 segundos
# Imagen intermedia guardada en ./Imagenes/Pycuda/dotplot_5.png
# Progreso: 162000/2676496 pasos completados. Tiempo transcurrido: 3130.52 segundos. Tiempo restante estimado: 48590.59 segundos
# Progreso: 164000/2676496 pasos completados. Tiempo transcurrido: 3168.92 segundos. Tiempo restante estimado: 48548.09 segundos
# Progreso: 166000/2676496 pasos completados. Tiempo transcurrido: 3207.31 segundos. Tiempo restante estimado: 48505.59 segundos
# Progreso: 168000/2676496 pasos completados. Tiempo transcurrido: 3244.87 segundos. Tiempo restante estimado: 48450.92 segundos
# Progreso: 170000/2676496 pasos completados. Tiempo transcurrido: 3282.95 segundos. Tiempo restante estimado: 48404.18 segundos
# Progreso: 172000/2676496 pasos completados. Tiempo transcurrido: 3321.27 segundos. Tiempo restante estimado: 48361.05 segundos
# Progreso: 174000/2676496 pasos completados. Tiempo transcurrido: 3359.61 segundos. Tiempo restante estimado: 48318.46 segundos
# Progreso: 176000/2676496 pasos completados. Tiempo transcurrido: 3397.13 segundos. Tiempo restante estimado: 48264.21 segundos
# Progreso: 178000/2676496 pasos completados. Tiempo transcurrido: 3435.75 segundos. Tiempo restante estimado: 48225.93 segundos
# Progreso: 180000/2676496 pasos completados. Tiempo transcurrido: 3474.46 segundos. Tiempo restante estimado: 48188.77 segundos
# Progreso: 182000/2676496 pasos completados. Tiempo transcurrido: 3514.12 segundos. Tiempo restante estimado: 48164.58 segundos
# Progreso: 184000/2676496 pasos completados. Tiempo transcurrido: 3551.06 segundos. Tiempo restante estimado: 48103.31 segundos
# Progreso: 186000/2676496 pasos completados. Tiempo transcurrido: 3589.27 segundos. Tiempo restante estimado: 48059.43 segundos
# Progreso: 188000/2676496 pasos completados. Tiempo transcurrido: 3627.77 segundos. Tiempo restante estimado: 48019.59 segundos
# Progreso: 190000/2676496 pasos completados. Tiempo transcurrido: 3666.40 segundos. Tiempo restante estimado: 47981.57 segundos
# Progreso: 192000/2676496 pasos completados. Tiempo transcurrido: 3704.93 segundos. Tiempo restante estimado: 47942.14 segundos
# Imagen intermedia guardada en ./Imagenes/Pycuda/dotplot_6.png
# Progreso: 194000/2676496 pasos completados. Tiempo transcurrido: 3742.23 segundos. Tiempo restante estimado: 47886.97 segundos
# Progreso: 196000/2676496 pasos completados. Tiempo transcurrido: 3781.76 segundos. Tiempo restante estimado: 47860.47 segundos
# Progreso: 198000/2676496 pasos completados. Tiempo transcurrido: 3820.16 segundos. Tiempo restante estimado: 47819.43 segundos
# Progreso: 200000/2676496 pasos completados. Tiempo transcurrido: 3858.18 segundos. Tiempo restante estimado: 47773.90 segundos
# Progreso: 202000/2676496 pasos completados. Tiempo transcurrido: 3895.41 segundos. Tiempo restante estimado: 47718.72 segundos
# Progreso: 204000/2676496 pasos completados. Tiempo transcurrido: 3933.60 segundos. Tiempo restante estimado: 47675.56 segundos
# Progreso: 206000/2676496 pasos completados. Tiempo transcurrido: 3970.38 segundos. Tiempo restante estimado: 47615.60 segundos
# Progreso: 208000/2676496 pasos completados. Tiempo transcurrido: 4008.39 segundos. Tiempo restante estimado: 47570.66 segundos
# Progreso: 210000/2676496 pasos completados. Tiempo transcurrido: 4044.97 segundos. Tiempo restante estimado: 47509.09 segundos
# Progreso: 212000/2676496 pasos completados. Tiempo transcurrido: 4083.93 segundos. Tiempo restante estimado: 47475.57 segundos
# Progreso: 214000/2676496 pasos completados. Tiempo transcurrido: 4121.37 segundos. Tiempo restante estimado: 47424.54 segundos
# Progreso: 216000/2676496 pasos completados. Tiempo transcurrido: 4159.62 segundos. Tiempo restante estimado: 47382.99 segundos
# Progreso: 218000/2676496 pasos completados. Tiempo transcurrido: 4197.15 segundos. Tiempo restante estimado: 47333.38 segundos
# Progreso: 220000/2676496 pasos completados. Tiempo transcurrido: 4236.69 segundos. Tiempo restante estimado: 47306.40 segundos
# Progreso: 222000/2676496 pasos completados. Tiempo transcurrido: 4274.33 segundos. Tiempo restante estimado: 47258.25 segundos
# Progreso: 224000/2676496 pasos completados. Tiempo transcurrido: 4313.05 segundos. Tiempo restante estimado: 47222.02 segundos
# Imagen intermedia guardada en ./Imagenes/Pycuda/dotplot_7.png
# Progreso: 226000/2676496 pasos completados. Tiempo transcurrido: 4352.12 segundos. Tiempo restante estimado: 47189.59 segundos
# Progreso: 228000/2676496 pasos completados. Tiempo transcurrido: 4391.33 segundos. Tiempo restante estimado: 47158.62 segundos
# Progreso: 230000/2676496 pasos completados. Tiempo transcurrido: 4428.12 segundos. Tiempo restante estimado: 47101.67 segundos
# Progreso: 232000/2676496 pasos completados. Tiempo transcurrido: 4466.27 segundos. Tiempo restante estimado: 47059.40 segundos
# Progreso: 234000/2676496 pasos completados. Tiempo transcurrido: 4505.89 segundos. Tiempo restante estimado: 47032.55 segundos
# Progreso: 236000/2676496 pasos completados. Tiempo transcurrido: 4543.85 segundos. Tiempo restante estimado: 46988.32 segundos
# Progreso: 238000/2676496 pasos completados. Tiempo transcurrido: 4581.28 segundos. Tiempo restante estimado: 46938.84 segundos
# Progreso: 240000/2676496 pasos completados. Tiempo transcurrido: 4618.81 segundos. Tiempo restante estimado: 46890.51 segundos
# Progreso: 242000/2676496 pasos completados. Tiempo transcurrido: 4659.23 segundos. Tiempo restante estimado: 46871.36 segundos
# Progreso: 244000/2676496 pasos completados. Tiempo transcurrido: 4696.75 segundos. Tiempo restante estimado: 46823.05 segundos
# Progreso: 246000/2676496 pasos completados. Tiempo transcurrido: 4734.19 segundos. Tiempo restante estimado: 46774.12 segundos
# Progreso: 248000/2676496 pasos completados. Tiempo transcurrido: 4770.83 segundos. Tiempo restante estimado: 46717.48 segundos
# Progreso: 250000/2676496 pasos completados. Tiempo transcurrido: 4809.25 segundos. Tiempo restante estimado: 46678.51 segundos
# Progreso: 252000/2676496 pasos completados. Tiempo transcurrido: 4846.47 segundos. Tiempo restante estimado: 46627.92 segundos
# Progreso: 254000/2676496 pasos completados. Tiempo transcurrido: 4883.45 segundos. Tiempo restante estimado: 46575.37 segundos
# Progreso: 256000/2676496 pasos completados. Tiempo transcurrido: 4920.22 segundos. Tiempo restante estimado: 46520.96 segundos
# Imagen intermedia guardada en ./Imagenes/Pycuda/dotplot_8.png
# Progreso: 258000/2676496 pasos completados. Tiempo transcurrido: 4959.31 segundos. Tiempo restante estimado: 46488.65 segundos
# Progreso: 260000/2676496 pasos completados. Tiempo transcurrido: 4997.85 segundos. Tiempo restante estimado: 46451.07 segundos
# Progreso: 262000/2676496 pasos completados. Tiempo transcurrido: 5037.19 segundos. Tiempo restante estimado: 46420.93 segundos
# Progreso: 264000/2676496 pasos completados. Tiempo transcurrido: 5076.33 segundos. Tiempo restante estimado: 46388.77 segundos
# Progreso: 266000/2676496 pasos completados. Tiempo transcurrido: 5115.82 segundos. Tiempo restante estimado: 46359.60 segundos
# Progreso: 268000/2676496 pasos completados. Tiempo transcurrido: 5153.71 segundos. Tiempo restante estimado: 46316.02 segundos
# Progreso: 270000/2676496 pasos completados. Tiempo transcurrido: 5191.54 segundos. Tiempo restante estimado: 46271.94 segundos
# Progreso: 272000/2676496 pasos completados. Tiempo transcurrido: 5229.50 segundos. Tiempo restante estimado: 46229.06 segundos
# Progreso: 274000/2676496 pasos completados. Tiempo transcurrido: 5267.97 segundos. Tiempo restante estimado: 46190.79 segundos
# Progreso: 276000/2676496 pasos completados. Tiempo transcurrido: 5304.78 segundos. Tiempo restante estimado: 46138.04 segundos
# Progreso: 278000/2676496 pasos completados. Tiempo transcurrido: 5340.73 segundos. Tiempo restante estimado: 46078.10 segundos
# Progreso: 280000/2676496 pasos completados. Tiempo transcurrido: 5378.39 segundos. Tiempo restante estimado: 46033.16 segundos
# Progreso: 282000/2676496 pasos completados. Tiempo transcurrido: 5417.20 segundos. Tiempo restante estimado: 45998.06 segundos
# Progreso: 284000/2676496 pasos completados. Tiempo transcurrido: 5454.13 segundos. Tiempo restante estimado: 45947.12 segundos
# Progreso: 286000/2676496 pasos completados. Tiempo transcurrido: 5489.68 segundos. Tiempo restante estimado: 45884.82 segundos
# Progreso: 288000/2676496 pasos completados. Tiempo transcurrido: 5526.54 segundos. Tiempo restante estimado: 45833.74 segundos
# Imagen intermedia guardada en ./Imagenes/Pycuda/dotplot_9.png
# Progreso: 290000/2676496 pasos completados. Tiempo transcurrido: 5565.61 segundos. Tiempo restante estimado: 45801.07 segundos
# Progreso: 292000/2676496 pasos completados. Tiempo transcurrido: 5602.68 segundos. Tiempo restante estimado: 45751.97 segundos
# Progreso: 294000/2676496 pasos completados. Tiempo transcurrido: 5639.18 segundos. Tiempo restante estimado: 45698.41 segundos
# Progreso: 296000/2676496 pasos completados. Tiempo transcurrido: 5677.32 segundos. Tiempo restante estimado: 45658.21 segundos
# Progreso: 298000/2676496 pasos completados. Tiempo transcurrido: 5717.09 segundos. Tiempo restante estimado: 45631.14 segundos
# Progreso: 300000/2676496 pasos completados. Tiempo transcurrido: 5755.49 segundos. Tiempo restante estimado: 45593.03 segundos
# Progreso: 302000/2676496 pasos completados. Tiempo transcurrido: 5791.91 segundos. Tiempo restante estimado: 45539.31 segundos
# Progreso: 304000/2676496 pasos completados. Tiempo transcurrido: 5828.93 segundos. Tiempo restante estimado: 45490.51 segundos
# Progreso: 306000/2676496 pasos completados. Tiempo transcurrido: 5867.73 segundos. Tiempo restante estimado: 45455.67 segundos
# Progreso: 308000/2676496 pasos completados. Tiempo transcurrido: 5904.50 segundos. Tiempo restante estimado: 45405.15 segundos
# Progreso: 310000/2676496 pasos completados. Tiempo transcurrido: 5940.20 segundos. Tiempo restante estimado: 45346.67 segundos
# Progreso: 312000/2676496 pasos completados. Tiempo transcurrido: 5977.02 segundos. Tiempo restante estimado: 45296.94 segundos
# Progreso: 314000/2676496 pasos completados. Tiempo transcurrido: 6015.08 segundos. Tiempo restante estimado: 45256.66 segundos
# Progreso: 316000/2676496 pasos completados. Tiempo transcurrido: 6051.58 segundos. Tiempo restante estimado: 45204.82 segundos
# Progreso: 318000/2676496 pasos completados. Tiempo transcurrido: 6087.75 segundos. Tiempo restante estimado: 45150.76 segundos
# Progreso: 320000/2676496 pasos completados. Tiempo transcurrido: 6124.63 segundos. Tiempo restante estimado: 45102.05 segundos
# Progreso: 322000/2676496 pasos completados. Tiempo transcurrido: 6161.64 segundos. Tiempo restante estimado: 45054.52 segundos
# Imagen intermedia guardada en ./Imagenes/Pycuda/dotplot_10.png
# Progreso: 324000/2676496 pasos completados. Tiempo transcurrido: 6199.38 segundos. Tiempo restante estimado: 45012.36 segundos
# Progreso: 326000/2676496 pasos completados. Tiempo transcurrido: 6236.52 segundos. Tiempo restante estimado: 44966.03 segundos
# Progreso: 328000/2676496 pasos completados. Tiempo transcurrido: 6273.88 segundos. Tiempo restante estimado: 44921.27 segundos
# Progreso: 330000/2676496 pasos completados. Tiempo transcurrido: 6311.14 segundos. Tiempo restante estimado: 44875.94 segundos
# Progreso: 332000/2676496 pasos completados. Tiempo transcurrido: 6348.86 segundos. Tiempo restante estimado: 44833.95 segundos
# Progreso: 334000/2676496 pasos completados. Tiempo transcurrido: 6385.98 segundos. Tiempo restante estimado: 44787.83 segundos
# Progreso: 336000/2676496 pasos completados. Tiempo transcurrido: 6423.58 segundos. Tiempo restante estimado: 44745.15 segundos
# Progreso: 338000/2676496 pasos completados. Tiempo transcurrido: 6460.83 segundos. Tiempo restante estimado: 44700.09 segundos
# Progreso: 340000/2676496 pasos completados. Tiempo transcurrido: 6498.96 segundos. Tiempo restante estimado: 44661.15 segundos
# Progreso: 342000/2676496 pasos completados. Tiempo transcurrido: 6535.50 segundos. Tiempo restante estimado: 44611.37 segundos
# Progreso: 344000/2676496 pasos completados. Tiempo transcurrido: 6572.60 segundos. Tiempo restante estimado: 44565.59 segundos
# Progreso: 346000/2676496 pasos completados. Tiempo transcurrido: 6609.75 segundos. Tiempo restante estimado: 44520.20 segundos
# Progreso: 348000/2676496 pasos completados. Tiempo transcurrido: 6647.93 segundos. Tiempo restante estimado: 44481.87 segundos
# Progreso: 350000/2676496 pasos completados. Tiempo transcurrido: 6684.19 segundos. Tiempo restante estimado: 44430.66 segundos
# Progreso: 352000/2676496 pasos completados. Tiempo transcurrido: 6721.08 segundos. Tiempo restante estimado: 44383.86 segundos
# Progreso: 354000/2676496 pasos completados. Tiempo transcurrido: 6758.26 segundos. Tiempo restante estimado: 44339.10 segundos
# Progreso: 356000/2676496 pasos completados. Tiempo transcurrido: 6794.09 segundos. Tiempo restante estimado: 44285.59 segundos
# Imagen intermedia guardada en ./Imagenes/Pycuda/dotplot_11.png
# Progreso: 358000/2676496 pasos completados. Tiempo transcurrido: 6832.61 segundos. Tiempo restante estimado: 44249.69 segundos
# Progreso: 360000/2676496 pasos completados. Tiempo transcurrido: 6869.77 segundos. Tiempo restante estimado: 44204.96 segundos
# Progreso: 362000/2676496 pasos completados. Tiempo transcurrido: 6906.88 segundos. Tiempo restante estimado: 44160.05 segundos
# Progreso: 364000/2676496 pasos completados. Tiempo transcurrido: 6942.77 segundos. Tiempo restante estimado: 44107.52 segundos
# Progreso: 366000/2676496 pasos completados. Tiempo transcurrido: 6981.04 segundos. Tiempo restante estimado: 44070.14 segundos
# Progreso: 368000/2676496 pasos completados. Tiempo transcurrido: 7018.45 segundos. Tiempo restante estimado: 44027.36 segundos
# Progreso: 370000/2676496 pasos completados. Tiempo transcurrido: 7055.33 segundos. Tiempo restante estimado: 43981.31 segundos
# Progreso: 372000/2676496 pasos completados. Tiempo transcurrido: 7091.25 segundos. Tiempo restante estimado: 43929.44 segundos
